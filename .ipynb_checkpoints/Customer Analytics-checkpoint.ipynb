# %% [markdown]
# # <center>Customer Analytics</center>

# %% [markdown]
# # 1. Business Understanding
# ---
# ## Segmentation data - Legend
# The dataset consists of information about the purchasing behavior of 2,000 individuals from a given area when entering a physical ‘FMCG’ store. All data has been collected through the loyalty cards they use at checkout. The data has been preprocessed and there are no missing values. In addition, the volume of the dataset has been restricted and anonymised to protect the privacy of the customers.
#
# <img src="images/1 data dictionary.png"/>

# %% [markdown]
# # 2. Data Understanding
# ---
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
sns.set()

from sklearn.preprocessing import StandardScaler

from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans

from sklearn.decomposition import PCA

import pickle

# %% [markdown]
# ## Import Data

# %%
# Setting ID column as Index
df_segmentation = pd.read_csv("data/segmentation data.csv",index_col="ID")
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %% [markdown]
# ## Explore Data

# %%
# Descriptive Statistics of the dataset
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# 75%       1.000000         1.000000
# max       2.000000         2.000000

# %% [markdown]
# #### `Customer's Age`
# * Minimum age is 18 and Maximum age is 76, so the **Range of age** is **58**
# * Average age is 36 approx.
#
# #### `Customer's Income (USD)`
# * Minimum income is 36,000 approx and Maximum income is 310,000, so the **Range of Income** is **274,000**
# * Average income is 121,000

# %% [markdown]
# ## Correlation Estimate
# **is used to learn the relationships among the different variables**
# </br>
#
# **Pearson Correlation-default in Python :** `describes Linear Dependency between variables`
# * **+1 Correlation :** `indicates Strong Positive Correlation`
# * **0 Correlation :** `indicates No Correlation i.e they are Linearly Independent`
# * **-1 Correlation :** `indicates Strong Negative Correlation`

# %%
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %%
title_style = {'fontsize': 30,
        'fontweight': "bold",
        'color': "black"}

label_style = {'fontsize': 25,
        'fontweight': "bold",
        'color': "b"}

# %%
plt.figure(figsize=(18,10))
s = sns.heatmap(df_segmentation.corr(),
               annot=True,
                cmap="RdBu",
                vmax=1,
                vmin=-1
               )
plt.title("Correlation Heatmap", fontdict= title_style)
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Visualize Raw Data

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data= df_segmentation, x = df_segmentation.Age, y = df_segmentation.Income)

plt.title("Age vs Income",fontdict= title_style)
plt.xlabel("Age", fontdict=label_style)
plt.ylabel("Income", fontdict=label_style)

plt.show()

# %% [markdown]
# # 3. Data Preparation
# ---
# ## Standardization

# %%
scaler = StandardScaler()
df_segmentation_standardized = scaler.fit_transform(df_segmentation)

# %%
pd.DataFrame(df_segmentation_standardized)
# Out:
#              0         1         2         3         4         5         6
# 0    -0.917399 -0.993024  2.653614  1.604323  0.097524  0.296823  1.552326
# 1     1.090038  1.007025 -1.187132 -0.063372  0.782654  0.296823  1.552326
# 2    -0.917399 -0.993024  1.117316 -0.063372 -0.833202 -1.269525 -0.909730
# 3    -0.917399 -0.993024  0.775916 -0.063372  1.328386  0.296823  0.321298
# 4    -0.917399 -0.993024  1.458716 -0.063372  0.736932  0.296823  0.321298
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  1.090038 -0.993024  0.946616 -0.063372  0.067471 -1.269525 -0.909730
# 1996  1.090038  1.007025 -0.760382 -0.063372 -0.084265  0.296823 -0.909730
# 1997 -0.917399 -0.993024 -0.418983 -1.731068 -0.906957 -1.269525 -0.909730
# 1998  1.090038  1.007025 -1.016432 -0.063372 -0.603329 -1.269525 -0.909730
# 1999 -0.917399 -0.993024 -0.931082 -1.731068 -1.378987 -1.269525 -0.909730
#
# [2000 rows x 7 columns]

# %% [markdown]
# # 4. Modelling
# ---
# ## Hierarchical Clustering : `for Customer Analytics & Segmentation`
# * **dendrogram :** `tree-like hierarchical, representation of points`
# * **linkage :** `specific employed method like ward`

# %%
# Returns Cluster result as Linkage Matrix
hierarchical_cluster = linkage(df_segmentation_standardized, method="ward")

# %%
# Represent Linkage Matrix using dendrogram
plt.figure(figsize=(18,10))
dendrogram(hierarchical_cluster,
           truncate_mode="level",
           p=5,
           show_leaf_counts=False, 
           no_labels=True)

plt.title("Hierarchical Clustering Dendrogram", fontdict=title_style)

plt.xlabel("Observations", fontdict=label_style)
plt.ylabel("Distance", fontdict=label_style)

plt.show()

# %% [markdown]
# ## K-means Clustering
# ---
# ### K-means++ `is an initialization algorithm that runs before the actual K-means algorithm to find the best cluster seeds i.e the best starting point for the centroids`
#
# **WCSS:** `Within Clusters Sum of Squares`

# %%
# The wcss value is stored in kmeans.inertia_ attribute
wcss = [] 

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42) # Creating kmeans object
    kmeans.fit(df_segmentation_standardized)
    wcss.append(kmeans.inertia_)

# %%
# Plotting wcss values

plt.figure(figsize=(18,10))
plt.plot(range(1,11), wcss, marker="o", linestyle="--")

plt.title("WCSS values for 10 different K values",fontdict=title_style)
plt.xlabel("Values of K", fontdict=label_style)
plt.ylabel("WCSS values", fontdict=label_style)
plt.show()

# %% [markdown]
# **To find the best value of K we needed WCSS values and it seems K=4 is the best value according to the Elbow method**

# %%
# Creating kmeans object
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
kmeans.fit(df_segmentation_standardized)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# ## Analyzing Result

# %%
# Making a copy of the orginal Segmentation dataset
df_segmentation_kmeans = df_segmentation.copy()

# %%
# Inserting a new column with the predicted Cluster or Segment lables by the model
df_segmentation_kmeans["Segment K-means"] = kmeans.labels_

# %%
df_segmentation_kmeans.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size  Segment K-means
# ID
# 100000001                2                0
# 100000002                2                2
# 100000003                0                1
# 100000004                1                3
# 100000005                1                3

# %% [markdown]
# #### Analyzing mean of the variables wrt each Clusters or Segments

# %%
df_segment_analysis = df_segmentation_kmeans.groupby(["Segment K-means"]).mean()
df_segment_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.853901        0.997163  28.963121   1.068085
# 3                0.029825        0.173684  35.635088   0.733333
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                158338.422053    1.129278         1.110266
# 1                 97859.852814    0.329004         0.043290
# 2                105759.119149    0.634043         0.422695
# 3                141218.249123    1.271930         1.522807

# %% [markdown]
# #### `Cluster 0`
# * *The customers are in their 50s*
# * *Average income is approx. 158,000 USD which is the highest among the Segments*
# * *This Segment contains equal number of Men and Women, since average sex is 0.5*
# * *Almost 70% of them are in Relationship since average Marital Status is 0.692*
# * *And this happens to be cluster of oldest customer since the average age is highest than the others*
# * *They are skilled and doing good jobs since average occupation is 1.1 in big cities since Settlement size is 1.1*
# * *Basically, they are doing well with their life*
# * Customers are **Well-Off**</br>
#
# #### `Cluster 1`
# * *The customers are in their 30s living in small cities*
# * *Average income is approx. 98,000 USD*
# * *36% of the customers are female*
# * *Almost all the customers are single*
# * *With lowest average income among the Segments*
# * *These customers are not doing well in their life*</br>
# * *They are not that skilled or unemployed since average occupation is 0.3*
# * *They are living in small cities since average Settlement size is 0.42* </br>
# * Customers have **Few Opportunities** </br>
#
# #### `Cluster 2`
# * *This is the youngest Segment with average age of 29*
# * *Almost all of them are in relationship since marital status is 99%*
# * *Earning standard income*
# * *Their life is Average*
# * *They are not that skilled since average occupation is 0.6*
# * Customers are **Standard** </br>
#
# #### `Cluster 3`
# * *The average age of the customers in this Segment is approx. 36 and average income is approx. 141,000 USD*
# * *29% of them are female i.e most of them are male*
# * *17% of them are in relationship*
# * *They are highly skilled and doing good jobs since average occupation is 1.3 in big cities since Settlement size is 1.5*
# * Customers are **Career Focused**

# %%
# Adding Number of customers per Clusters or Segments
df_segment_analysis["No. of Observation"] = df_segmentation_kmeans[["Segment K-means","Sex"]].groupby\
(["Segment K-means"]).count()

# %%
df_segment_analysis["Proportion of Obsv"] = df_segment_analysis["No. of Observation"]/df_segment_analysis\
["No. of Observation"].sum()

# %%
df_segment_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.853901        0.997163  28.963121   1.068085
# 3                0.029825        0.173684  35.635088   0.733333
#
#                         Income  Occupation  Settlement size  \
# Segment K-means
# 0                158338.422053    1.129278         1.110266
# 1                 97859.852814    0.329004         0.043290
# 2                105759.119149    0.634043         0.422695
# 3                141218.249123    1.271930         1.522807
#
#                  No. of Observation  Proportion of Obsv
# Segment K-means
# 0                               263              0.1315
# 1                               462              0.2310
# 2                               705              0.3525
# 3                               570              0.2850

# %% [markdown]
# #### Renaming the Segments/Clusters

# %%
df_segment_analysis.rename({
    0:"Well-Off",
    1:"Fewer-Opportunities",
    2:"Standard",
    3:"Career-Focused"
})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means
# Well-Off             0.501901        0.692015  55.703422   2.129278
# Fewer-Opportunities  0.352814        0.019481  35.577922   0.746753
# Standard             0.853901        0.997163  28.963121   1.068085
# Career-Focused       0.029825        0.173684  35.635088   0.733333
#
#                             Income  Occupation  Settlement size  \
# Segment K-means
# Well-Off             158338.422053    1.129278         1.110266
# Fewer-Opportunities   97859.852814    0.329004         0.043290
# Standard             105759.119149    0.634043         0.422695
# Career-Focused       141218.249123    1.271930         1.522807
#
#                      No. of Observation  Proportion of Obsv
# Segment K-means
# Well-Off                            263              0.1315
# Fewer-Opportunities                 462              0.2310
# Standard                            705              0.3525
# Career-Focused                      570              0.2850

# %% [markdown]
# #### Well-Off Cluster
# * `Customers are the lowest in proprtion only 13% i.e 263 customers out of 2000`</br>
#
# #### Fewer-Opportunities Cluster
# * `Customers are in in proprtion of 23% i.e 462 customers out of 2000`</br>
#
# #### Standard Cluster
# * `Customers are the highest in proprtion of 35% i.e 705 customers out of 2000`</br>
#
# #### Career-Focused Cluster
# * `Customers are in proprtion of 29% i.e 570 customers out of 2000`</br>

# %% [markdown]
# ### Labelling the kmeans dataset with Segment Labels via `.map()`

# %%
df_segmentation_kmeans["Segment Labels"] = df_segmentation_kmeans["Segment K-means"].map({
    0:"Well-Off",
    1:"Fewer-Opportunities",
    2:"Standard",
    3:"Career-Focused"})

# %%
df_segmentation_kmeans
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
# ...        ...             ...  ...        ...     ...         ...
# 100001996    1               0   47          1  123525           0
# 100001997    1               1   27          1  117744           1
# 100001998    0               0   31          0   86400           0
# 100001999    1               1   24          1   97968           0
# 100002000    0               0   25          0   68416           0
#
#            Settlement size  Segment K-means       Segment Labels
# ID
# 100000001                2                0             Well-Off
# 100000002                2                2             Standard
# 100000003                0                1  Fewer-Opportunities
# 100000004                1                3       Career-Focused
# 100000005                1                3       Career-Focused
# ...                    ...              ...                  ...
# 100001996                0                1  Fewer-Opportunities
# 100001997                0                2             Standard
# 100001998                0                1  Fewer-Opportunities
# 100001999                0                2             Standard
# 100002000                0                1  Fewer-Opportunities
#
# [2000 rows x 9 columns]

# %% [markdown]
# #### Visualizing the dataset

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data=df_segmentation_kmeans, x="Age",y="Income", hue="Segment Labels")
plt.show()

# %% [markdown]
# * *Only the Well-Off Segment is segmented nicely and are separate from the others and are clearly visible, whereas, others are messed up, therefore we will use PCA to achive better result*

# %% [markdown]
# ## PCA ( Principal Component Analysis )
# **Used for Dimensionality Reduction of our data**

# %%
df_segmentation_standardized.shape
# Out:
# (2000, 7)

# %%
# Instantiation of PCA class
pca = PCA()

# %%
# Applying PCA on standardized segmentation dataset to Reduce its Dimensions
pca.fit(df_segmentation_standardized)
# Out:
# PCA()

# %% [markdown]
# **PCA creates number of components equal to the number of features in the dataset i.e 7 and moreover, these components are arranged in their order of their importance, and here importance indicates how much of the variance of our data is explained by each component.**
# </br>
#
# **PCA Components**

# %%
# Returns Loading
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503],
#        [-0.31560091,  0.28045392, -0.00950602,  0.18147643, -0.48260023,
#         -0.28169039,  0.69026455],
#        [-0.70718503,  0.49755981, -0.1351596 ,  0.10659686,  0.07889011,
#          0.13394187, -0.44556535],
#        [-0.05111859,  0.12551723, -0.09958614, -0.11433321,  0.66281185,
#         -0.70912085,  0.12833901],
#        [-0.05489292, -0.40390112, -0.62957581,  0.65781577,  0.05863312,
#         -0.03311512, -0.01512939]])

# %% [markdown]
# **Loading :** *is a correlation between original variables and components*

# %%
pca.components_.shape
# Out:
# (7, 7)

# %%
# PCA Components
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %% [markdown]
# * **The first two component is explaining almost 60% if the data**
# * **The above 7 components together explains 100% variability of the data, and if we add them all we get sum = 1**
# </br>
#
# **The task is now to select a subset of components wihile preserving most of the variance**

# %%
plt.figure(figsize=(18,10))

plt.plot(range(1,8),pca.explained_variance_ratio_.cumsum(), marker="o", linestyle="--")
plt.title("Explained Variance by Components",fontdict=title_style)
plt.xlabel("Number of Components", fontdict=label_style)
plt.ylabel("Cumulative Explained Variance", fontdict=label_style)
plt.show()

# %% [markdown]
# * **It's evident that the First 4 Component cumulatively explains or preserving almost 90% of the data, therefore keeping the 4 components and hence, we reduced the dimensions from 7 to 4**</br>
#
# #### Rule of thumb : `We must preserve atleast 80% of the data`

# %%
# Reinitializing the PCA
pca = PCA(n_components=4)

# %%
pca.fit(df_segmentation_standardized)
# Out:
# PCA(n_components=4)

# %% [markdown]
# ## PCA Result Analysis

# %%
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503],
#        [-0.31560091,  0.28045392, -0.00950602,  0.18147643, -0.48260023,
#         -0.28169039,  0.69026455]])

# %%
df_pca_components = pd.DataFrame(pca.components_, columns=df_segmentation.columns.values,\
                                 index = ["Component1","Component2", "Component3","Component4"])

df_pca_components
# Out:
#                  Sex  Marital status       Age  Education    Income  \
# Component1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
# Component4 -0.315601        0.280454 -0.009506   0.181476 -0.482600
#
#             Occupation  Settlement size
# Component1    0.492059         0.464789
# Component2    0.014658        -0.069632
# Component3   -0.395505        -0.295685
# Component4   -0.281690         0.690265

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df_pca_components,vmin=-1, vmax=1,cmap="RdBu",annot=True)
plt.title("Correlation between PCA Components and Variables",fontdict=title_style)
plt.show()

# %% [markdown]
# **Reducing the Dimensions of our data**

# %%
# Dimensions reduced from 7D data to 4D PCA scores
pca_scores = pca.transform(df_segmentation_standardized)
pca_scores
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ,  1.21779432],
#        [ 0.34493528,  0.59814564, -2.21160279,  0.54838542],
#        [-0.65106267, -0.68009318,  2.2804186 ,  0.12067518],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125, -0.13177412],
#        [-2.24145254,  0.62710847, -0.53045631, -0.04260559],
#        [-1.86688505, -2.45467234,  0.66262172,  0.10089556]])

# %% [markdown]
# **Note:** that pca component scores are standardized by definition

# %% [markdown]
# ### K-means Clustering with PCA

# %%
wcss = []

for i in range(1,11):
    kmeans_pca = KMeans(n_clusters=i,random_state=42)
    kmeans_pca.fit(pca_scores)
    wcss.append(kmeans_pca.inertia_)

wcss
# Out:
# [12365.656111930679,
#  8880.414629426376,
#  7002.3923732996445,
#  5550.669973206837,
#  4844.605934763395,
#  4280.231528082553,
#  3832.92150834165,
#  3498.065117404712,
#  3158.496071065373,
#  2892.09179688451]

# %%
plt.figure(figsize=(18,10))
plt.plot(range(1,11),wcss, marker="o", linestyle="--")
plt.title("WCSS values for 10 different K", fontdict=title_style)
plt.xlabel("K Values", fontdict=label_style)
plt.ylabel("WCSS Values", fontdict=label_style)
plt.show()

# %% [markdown]
# **To find the best value of K we needed WCSS values and it seems K=4 is the best value according to the Elbow method**

# %%
# Re-instantiating the model
kmeans_pca = KMeans(n_clusters=4,random_state=42)

# %%
kmeans_pca.fit(pca_scores)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
kmeans_pca.labels_
# Out:
# array([3, 0, 2, ..., 2, 0, 2], dtype=int32)

# %% [markdown]
# ## K-means Clustering with PCA result analysis

# %%
df_segmentation.reset_index(drop=True).head(2)
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2

# %%
df_pca_scores = pd.DataFrame(pca_scores)
df_pca_scores.head(2)
# Out:
#           0         1         2         3
# 0  2.514746  0.834122  2.174806  1.217794
# 1  0.344935  0.598146 -2.211603  0.548385

# %%
# Concatenating or Adding the PCA Scores Variables in the original dataset
df_segmentation_kmeans_pca = pd.concat([df_segmentation.reset_index(drop=True), df_pca_scores], axis = 1)
df_segmentation_kmeans_pca
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  \
# 0       0               0   67          2  124670           1
# 1       1               1   22          1  150773           1
# 2       0               0   49          1   89210           0
# 3       0               0   45          1  171565           1
# 4       0               0   53          1  149031           1
# ...   ...             ...  ...        ...     ...         ...
# 1995    1               0   47          1  123525           0
# 1996    1               1   27          1  117744           1
# 1997    0               0   31          0   86400           0
# 1998    1               1   24          1   97968           0
# 1999    0               0   25          0   68416           0
#
#       Settlement size         0         1         2         3
# 0                   2  2.514746  0.834122  2.174806  1.217794
# 1                   2  0.344935  0.598146 -2.211603  0.548385
# 2                   0 -0.651063 -0.680093  2.280419  0.120675
# 3                   1  1.714316 -0.579927  0.730731 -0.510753
# 4                   1  1.626745 -0.440496  1.244909 -0.231808
# ...               ...       ...       ...       ...       ...
# 1995                0 -0.866034  0.298330  1.438958 -0.945916
# 1996                0 -1.114957  0.794727 -1.079871 -0.736766
# 1997                0 -1.452298 -2.235937  0.896571 -0.131774
# 1998                0 -2.241453  0.627108 -0.530456 -0.042606
# 1999                0 -1.866885 -2.454672  0.662622  0.100896
#
# [2000 rows x 11 columns]

# %%
# Rename the Added PCA scores Variable names
df_segmentation_kmeans_pca.columns.values[-4:] = ["Component1","Component2", "Component3", "Component4"]
df_segmentation_kmeans_pca.head(2)
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
#
#    Component1  Component2  Component3  Component4
# 0    2.514746    0.834122    2.174806    1.217794
# 1    0.344935    0.598146   -2.211603    0.548385

# %%
print(kmeans_pca.labels_)
print(type(kmeans_pca))
len(kmeans_pca.labels_)
# Out:
# [3 0 2 ... 2 0 2]
# <class 'sklearn.cluster._kmeans.KMeans'>
# 2000

# %%
# Adding Labels to the Dataset
df_segmentation_kmeans_pca["Segment K-means PCA"] = kmeans_pca.labels_

# %%
df_segmentation_kmeans_pca.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#    Component1  Component2  Component3  Component4  Segment K-means PCA
# 0    2.514746    0.834122    2.174806    1.217794                    3
# 1    0.344935    0.598146   -2.211603    0.548385                    0
# 2   -0.651063   -0.680093    2.280419    0.120675                    2
# 3    1.714316   -0.579927    0.730731   -0.510753                    1
# 4    1.626745   -0.440496    1.244909   -0.231808                    1

# %% [markdown]
# ### Analyzing the datset by Each `Segment K-means PCA`

# %%
df_segmentation_kmeans_pca_analysis = df_segmentation_kmeans_pca.groupby(["Segment K-means PCA"]).mean()
df_segmentation_kmeans_pca_analysis
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.905045        0.986647  28.873887   1.063798
# 1                    0.026178        0.178010  35.624782   0.734729
# 2                    0.319018        0.089980  35.259714   0.768916
# 3                    0.503788        0.689394  55.689394   2.128788
#
#                             Income  Occupation  Settlement size  Component1  \
# Segment K-means PCA
# 0                    107576.228487    0.672107         0.439169   -1.122432
# 1                    140950.319372    1.267016         1.520070    1.381089
# 2                     95850.155419    0.296524         0.038855   -0.987777
# 3                    158209.094697    1.125000         1.106061    1.697646
#
#                      Component2  Component3  Component4
# Segment K-means PCA
# 0                      0.733291   -0.797918   -0.019662
# 1                     -1.044848   -0.273292    0.211736
# 2                     -0.882022    0.965476   -0.271684
# 3                      2.029427    0.841953    0.093869

# %%
df_segmentation_kmeans_pca_analysis["No. of Observations"] = df_segmentation_kmeans_pca[["Segment K-means PCA",\
"Sex"]].groupby(["Segment K-means PCA"]).count()

# %%
df_segmentation_kmeans_pca_analysis
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.905045        0.986647  28.873887   1.063798
# 1                    0.026178        0.178010  35.624782   0.734729
# 2                    0.319018        0.089980  35.259714   0.768916
# 3                    0.503788        0.689394  55.689394   2.128788
#
#                             Income  Occupation  Settlement size  Component1  \
# Segment K-means PCA
# 0                    107576.228487    0.672107         0.439169   -1.122432
# 1                    140950.319372    1.267016         1.520070    1.381089
# 2                     95850.155419    0.296524         0.038855   -0.987777
# 3                    158209.094697    1.125000         1.106061    1.697646
#
#                      Component2  Component3  Component4  No. of Observations
# Segment K-means PCA
# 0                      0.733291   -0.797918   -0.019662                  674
# 1                     -1.044848   -0.273292    0.211736                  573
# 2                     -0.882022    0.965476   -0.271684                  489
# 3                      2.029427    0.841953    0.093869                  264

# %%
df_segmentation_kmeans_pca_analysis["Proportion of Observations"] = df_segmentation_kmeans_pca_analysis\
["No. of Observations"] / df_segmentation_kmeans_pca_analysis["No. of Observations"].sum()

# %%
df_segmentation_kmeans_pca_analysis
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.905045        0.986647  28.873887   1.063798
# 1                    0.026178        0.178010  35.624782   0.734729
# 2                    0.319018        0.089980  35.259714   0.768916
# 3                    0.503788        0.689394  55.689394   2.128788
#
#                             Income  Occupation  Settlement size  Component1  \
# Segment K-means PCA
# 0                    107576.228487    0.672107         0.439169   -1.122432
# 1                    140950.319372    1.267016         1.520070    1.381089
# 2                     95850.155419    0.296524         0.038855   -0.987777
# 3                    158209.094697    1.125000         1.106061    1.697646
#
#                      Component2  Component3  Component4  No. of Observations  \
# Segment K-means PCA
# 0                      0.733291   -0.797918   -0.019662                  674
# 1                     -1.044848   -0.273292    0.211736                  573
# 2                     -0.882022    0.965476   -0.271684                  489
# 3                      2.029427    0.841953    0.093869                  264
#
#                      Proportion of Observations
# Segment K-means PCA
# 0                                        0.3370
# 1                                        0.2865
# 2                                        0.2445
# 3                                        0.1320

# %%
# Rename Segment K-means PCA
df_segmentation_kmeans_pca_analysis = df_segmentation_kmeans_pca_analysis.rename({
    0:"Standard",
    1:"Career Focused",
    2:"Fewer Opprtunities",
    3:"Well-Off"
})

# %%
df_segmentation_kmeans_pca_analysis
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# Standard             0.905045        0.986647  28.873887   1.063798
# Career Focused       0.026178        0.178010  35.624782   0.734729
# Fewer Opprtunities   0.319018        0.089980  35.259714   0.768916
# Well-Off             0.503788        0.689394  55.689394   2.128788
#
#                             Income  Occupation  Settlement size  Component1  \
# Segment K-means PCA
# Standard             107576.228487    0.672107         0.439169   -1.122432
# Career Focused       140950.319372    1.267016         1.520070    1.381089
# Fewer Opprtunities    95850.155419    0.296524         0.038855   -0.987777
# Well-Off             158209.094697    1.125000         1.106061    1.697646
#
#                      Component2  Component3  Component4  No. of Observations  \
# Segment K-means PCA
# Standard               0.733291   -0.797918   -0.019662                  674
# Career Focused        -1.044848   -0.273292    0.211736                  573
# Fewer Opprtunities    -0.882022    0.965476   -0.271684                  489
# Well-Off               2.029427    0.841953    0.093869                  264
#
#                      Proportion of Observations
# Segment K-means PCA
# Standard                                 0.3370
# Career Focused                           0.2865
# Fewer Opprtunities                       0.2445
# Well-Off                                 0.1320

# %%
# Mapping the Legends to the dataset

# %%
df_segmentation_kmeans_pca["Legends"] = df_segmentation_kmeans_pca["Segment K-means PCA"].map({
    0:"Standard",
    1:"Career Focused",
    2:"Fewer Opprtunities",
    3:"Well-Off"
})

df_segmentation_kmeans_pca
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  \
# 0       0               0   67          2  124670           1
# 1       1               1   22          1  150773           1
# 2       0               0   49          1   89210           0
# 3       0               0   45          1  171565           1
# 4       0               0   53          1  149031           1
# ...   ...             ...  ...        ...     ...         ...
# 1995    1               0   47          1  123525           0
# 1996    1               1   27          1  117744           1
# 1997    0               0   31          0   86400           0
# 1998    1               1   24          1   97968           0
# 1999    0               0   25          0   68416           0
#
#       Settlement size  Component1  Component2  Component3  Component4  \
# 0                   2    2.514746    0.834122    2.174806    1.217794
# 1                   2    0.344935    0.598146   -2.211603    0.548385
# 2                   0   -0.651063   -0.680093    2.280419    0.120675
# 3                   1    1.714316   -0.579927    0.730731   -0.510753
# 4                   1    1.626745   -0.440496    1.244909   -0.231808
# ...               ...         ...         ...         ...         ...
# 1995                0   -0.866034    0.298330    1.438958   -0.945916
# 1996                0   -1.114957    0.794727   -1.079871   -0.736766
# 1997                0   -1.452298   -2.235937    0.896571   -0.131774
# 1998                0   -2.241453    0.627108   -0.530456   -0.042606
# 1999                0   -1.866885   -2.454672    0.662622    0.100896
#
#       Segment K-means PCA             Legends
# 0                       3            Well-Off
# 1                       0            Standard
# 2                       2  Fewer Opprtunities
# 3                       1      Career Focused
# 4                       1      Career Focused
# ...                   ...                 ...
# 1995                    2  Fewer Opprtunities
# 1996                    0            Standard
# 1997                    2  Fewer Opprtunities
# 1998                    0            Standard
# 1999                    2  Fewer Opprtunities
#
# [2000 rows x 13 columns]

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data=df_segmentation_kmeans_pca, x="Component2", y="Component1", hue="Legends")
plt.title("Clusters by PCA Components", fontdict=title_style)
plt.xlabel("Component2",fontdict=label_style)
plt.ylabel("Component1", fontdict=label_style)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(data=df_segmentation_kmeans_pca, x="Component1", y="Component3", hue="Legends")
plt.title("Clusters by PCA Components", fontdict=title_style)
plt.xlabel("Component1",fontdict=label_style)
plt.ylabel("Component3", fontdict=label_style)
plt.show()

# %% [markdown]
# ## Data Export
# **Pickle module :** `The pickle module implements binary protocols for serializing and de-serializing a Python object structure i.e converts python objects into streams and store them in .pickle file, so, next time when we need them in other places or notebook, we can simply import them and use them directly without any changes.`
# * **“Pickling”** is the process whereby a Python object hierarchy is converted into a byte stream, and
# * **“unpickling”** is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.`

# %%
pickle.dump(scaler, open("scaler.pickle","wb"))
pickle.dump(pca, open("pca.pickle","wb"))
pickle.dump(kmeans_pca, open("kmeans_pca.pickle","wb"))
